# %% [markdown]
# <a href="https://colab.research.google.com/github/david-j-cox/twitter-higher-ed/blob/main/topic_modeling_by_year_and_sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Packages and Modules

# %%
# For data manipulation
import pandas as pd
import numpy as np
import re

# For data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pprint import pprint
import wordcloud

# For topic modeling
import spacy
from spacy.lang.en import English
parser = English()
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet as wn
import gensim
from gensim import corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import spacy
try:
  import pyLDAvis
except:
  # !pip install pyLDAvis
  import pyLDAvis
import pyLDAvis.gensim_models
import pickle

# Connect to Google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Functions

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('TWITTER_HANDLE')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma

def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

def lda_model_grid(df, col):
  df_text = []
  for i in range(10):
      tokens = df[col][i]
      df_text.append(tok for tok in tokens)
      df_text.append(tokens)

  df_dict = corpora.Dictionary(df_text)
  df_corpus = [df_dict.doc2bow(text) for text in df[col]]

  # Create model and save
  topics = []
  complexity = []
  coherence = []
  for i in range(2, 10):
    print(f"Checking model with {i} topics.")
    # Build model
    lda_model = gensim.models.ldamodel.LdaModel(corpus=df_corpus, 
                                                  id2word=df_dict, 
                                                  num_topics=i, 
                                                  random_state=100,
                                                  update_every=1, 
                                                  chunksize=1000, 
                                                  passes=10, 
                                                  alpha='auto', 
                                                  per_word_topics=True)
    # Compute complexity and coherence score
    cmplx = lda_model.log_perplexity(df_corpus)
    coherence_model_lda = CoherenceModel(model=lda_model, 
                                        texts=df[col], 
                                        dictionary=df_dict, 
                                        coherence='c_v')
    coh = coherence_model_lda.get_coherence()
    topics.append(i)
    complexity.append(cmplx)
    coherence.append(coh)

  # Save as a df
  df_df = pd.DataFrame({'topics': topics, 
                        'complexity':complexity, 
                        'coherence':coherence})
  return df_df

def line_plot(df, col, save_name):
  plt.figure(figsize=(10, 7))
  sns.lineplot(x='topics', y=col, marker='o', 
                size=15, color='k', data=df, 
               legend=False)
  plt.ylabel(col, fontsize=24, labelpad=20)
  plt.yticks(fontsize=18)
  plt.xlabel("Topics", fontsize=24, labelpad=20)
  plt.xticks(fontsize=18)
  plt.savefig(f'{save_name}.png', bbox_inches='tight')
  plt.show()

def lda_one_topic(df, col, topics, savename):
  df_text = []
  for i in range(10):
      tokens = df[col][i]
      df_text.append(tok for tok in tokens)
      df_text.append(tokens)

  df_dict = corpora.Dictionary(df_text)
  df_corpus = [df_dict.doc2bow(text) for text in df[col]]

  # Build model
  lda_model = gensim.models.ldamodel.LdaModel(corpus=df_corpus, 
                                              id2word=df_dict, 
                                              num_topics=topics, 
                                              random_state=100,
                                              update_every=1, 
                                              chunksize=1000, 
                                              passes=10, 
                                              alpha='auto', 
                                              per_word_topics=True)
  lda_model.save(f'{savename}.gensim')
  all_topics = lda_model.print_topics(num_words=50)
  all_topics = pd.DataFrame(all_topics)
  all_topics.to_csv(f'topic_words_{savename}.csv')
  pyLDAvis.enable_notebook()
  lda_display = pyLDAvis.gensim_models.prepare(lda_model, 
                                              df_corpus, 
                                              df_dict, 
                                              sort_topics=False)
  pyLDAvis.display(lda_display)
  pyLDAvis.save_html(lda_display, f'lda_vis_{savename}.html')
  return all_topics

# %% [markdown]
# ## Read in data

# %%
# Import data
# raw_data = pd.read_csv('../data/03_primary/all_data.csv')
raw_data = pd.read_csv('/content/gdrive/MyDrive/Twitter-Higher-Ed/03_primary/all_data.csv')
data = raw_data.copy()
data.head()
# Out:
#    Unnamed: 0                           _type  ... text_blob_subjectivity  year
# 0           0  snscrape.modules.twitter.Tweet  ...               0.000000  2020
# 1           1  snscrape.modules.twitter.Tweet  ...               0.450000  2020
# 2           2  snscrape.modules.twitter.Tweet  ...               0.800000  2020
# 3           3  snscrape.modules.twitter.Tweet  ...               0.597024  2020
# 4           4  snscrape.modules.twitter.Tweet  ...               0.466667  2020
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Text Cleaning

# %%
# Clean up data for topic modeling
import random
text_data = []
for i in range(len(data)):
    tokens = prepare_text_for_lda(data['content'][i])
    text_data.append(tokens)
    if random.random()>0.999:
        print(tokens)
# Out:
# ['great', 'first', 'TWITTER_HANDLE', 'techieteabreak', 'morning', 'staff', 'join', 'things', 'digital', 'asking', 'question', 'sharing', 'idea', 'email', 'staff', 'teachershelpingteachers', 'digitallearning', 'digilearnscot', 'remotelearning']
# ['great', 'first', 'TWITTER_HANDLE', 'techieteabreak', 'morning', 'staff', 'join', 'things', 'digital', 'asking', 'question', 'sharing', 'idea', 'email', 'staff', 'teachershelpingteachers', 'digitallearning', 'digilearnscot', 'remotelearning']
# ['wonderful', 'thing', 'teacher', 'spend', 'child', 'hop', 'move', 'forward', 'blessing', 'virtually', 'digital', 'learning', 'book', 'great', 'together']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'course', 'thing', 'assess', 'anything', 'distance', 'learning', 'especially', 'anything', 'without', 'structure', 'place', 'online', 'course', 'teach', 'school', 'student', 'years', 'require', 'test', 'proctor', 'teacher', 'school']
# ['TWITTER_HANDLE', 'series', 'texan', 'confront', 'pandemic', 'include', 'TWITTER_HANDLE', 'story', 'houston', 'restaurant', 'owner', 'using', 'donation', 'frontline', 'worker', 'TWITTER_HANDLE', 'student', 'getting', 'online', 'teacher']
# ['anyways', 'professor', 'making', 'class', 'difficult', 'online']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'conversation', 'husband', 'teacher', 'think', 'exsisting', 'florida', 'virtual', 'might', 'expand', 'unfortunately', 'online', 'learning', 'require', 'specific', 'discipline']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'teaching', 'online', 'years', 'therefore', 'disruption', 'professor', 'TWITTER_HANDLE', 'university', 'prepare', 'others', 'coronavirus', 'impact']
# ['TWITTER_HANDLE', 'college', 'student', 'want', 'campus', 'experience', 'would', 'enroll', 'elsewhere', 'university', 'want', 'online', 'curriculum']
# ['add', 'TWITTER_HANDLE', 'online', 'teacher', 'onlinelearning', 'distancelearning', 'etec527', 'english2']
# ['online', 'teacher', 'course', 'explore', 'virtual', 'classroom', 'essential', 'social', 'medium', 'classroom', 'mastery', 'learning', 'basics', 'standard', 'base', 'grading', 'have']
# ['could', 'final', 'professor', 'posting', 'final', 'online', 'great']
# ['minister', 'education', 'public', 'university', 'conduct', 'exam', 'online', 'legon']
# ['stream', 'online', 'pilate', 'teacher', 'training', 'course']
# ['state', 'fully', 'online', 'summer', 'session', 'offer', 'university', 'course', 'academic', 'credit', 'current', 'student', 'public', 'register', 'mycsueb', 'follow', 'university', 'policy', 'process']
# ['TWITTER_HANDLE', 'university', 'start', 'place', 'respective', 'textbook', 'online', 'university', 'raise', 'ensure', 'topic', 'place', 'table', 'engagement', 'university', 'management']
# ['professor', 'coloca', 'online', 'pleno', 'feriado', 'brinca', 'muito']
# ['attend', 'search', 'beyond', 'professoriate', 'online', 'workshop', 'discus', 'employer', 'people', 'graduate', 'training', 'examine', 'position', 'beyond', 'professoriate', 'mechanics', 'search']
# ['câmera', 'baseado', 'fotos', 'cachorros', 'filhos', 'professores', 'tiradas', 'durante', 'online']
# ['louie', 'divinagracia', 'college', 'business', 'administration', 'university', 'caloocan', 'campus', 'among', 'keynote', 'speaker', 'online', 'event', 'public', 'student', 'faculty', 'member', 'professional']
# ['anyone', 'miss', 'school', 'assembly-', 'connectivity', 'inspirational', 'message', 'archbishop', 'canterbury', 'TWITTER_HANDLE', 'leading', 'inaugural', 'assembly', 'morning', 'TWITTER_HANDLE', 'online', 'classroom', 'resource', 'create', 'teacher', 'teacher', 'community']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'think', 'teacher', 'teaching', 'remotely', 'student', 'going', 'school', 'supervise', 'victorian', 'teacher', 'organise', 'remote', 'teaching', 'asynchronously', 'synchronous', 'contact', 'school']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'teacher', 'minimum', 'drinking', 'attempt', 'navigate', 'hours', 'certainly', 'involve']
# ['drop', 'first', 'meeting', 'teacher']
# ['tomorrow', 'deliver', 'digital', 'training', 'TWITTER_HANDLE', 'ahead', 'hitting', 'virtual', 'university', 'lecture', 'theatre', 'teach', 'lecture', 'crisiscommunications', 'master', 'student', 'ready']
# ['terrierpride', 'spirit', 'spiritweekohio', 'update', 'wallpaper', 'background', 'hiramcollege', 'design', 'TWITTER_HANDLE']
# ['yesterday', 'teacher', 'going', 'around', 'check', 'everyone', 'gimme', 'insane', 'since', 'people', 'actually', 'service']
# ['minutes', 'interview', 'professor']
# ['school', 'teacher', 'friend', 'learning', 'class', 'miss', 'unique', 'positive', 'community', 'create', 'try', 'going', 'today', 'TWITTER_HANDLE', 'version', 'corner', 'laughter!@whiteoaklions', 'TWITTER_HANDLE', 'TWITTER_HANDLE']
# ['TWITTER_HANDLE', 'could', 'agree', 'friend', 'private', 'school', 'seeing', 'teach', 'meanwhile', 'state', 'try', 'small', 'amount', 'work', 'teacher']
# ['mathclass', 'groupme', 'talking', 'random', 'stuff', 'make', 'better', 'professor', 'know', 'would', 'zoomclass', 'worst', 'student']
# ['listening', 'grader', 'teacher', 'class', 'sharing', 'feelings', 'parent', 'include', 'doctor', 'nurse', 'holding', 'together', 'despite', 'overwhelm', 'gratitude']
# ['update', 'dread', 'google', 'transition', 'adventure', 'homeschooling', 'teacher', 'trouble', 'google', 'ipads', 'garbage', 'teacher', 'tutorial', 'hide', 'feature']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE']
# ['parent', 'twitter', 'friend', 'teacher', 'adapt', 'quarantine', 'conducting', 'regular', 'class', 'google', 'classroom']
# ['เมื่อวันที่', 'เมษายน', 'ได้มีโอกาสบรรยาย', 'workshop', 'ในหัวข้อ', 'การวิจัยโดยใช้', 'microsoft', 'team', 'การทำข้อสอบและการตัดเกรด', 'lannacom', 'thammasatuniversity', 'microsoft', 'microsoftteams']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'microsoft', 'teams！！初めて知りました！！ファイルの共有ができるのはありがたいですね。いろいろなツールがあるんだなー！！勉強せねば・・']
# ['quick', 'advice', 'teacher', 'lockdown', 'would', 'teacher', 'conversant', 'technology', 'virtual', 'learning', 'start', 'learning', 'certain', 'tool', 'microsoft', 'team', 'microsoft', 'education', 'tachatakeover', 'covid19']
# ['nosso', 'professor', 'logística', 'deixou', 'microsoft', 'team', 'falando', 'sente', 'vazio', 'gente', 'muito', 'triste', 'ficar', 'longe', 'corona', 'favor', 'nunca', 'tanto', 'escola', 'preciso', 'amigo', 'professores', 'gosto']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'teacher', 'report', 'custom', 'background', 'background', 'feature', 'rollout', 'happen']
# ['earn', 'working', 'smart', 'using', 'microsoft', 'team', 'higher', 'education', 'microsoft', 'educator', 'center', 'check', 'course', 'TWITTER_HANDLE']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'team', 'trivia', 'thing', 'bottom']
# ['today', 'world', 'autism', 'awareness', 'student', 'autistic', 'group', 'student', 'belonging', 'connect', 'safety', 'university', 'twice', 'microsoft', 'team', 'visiting', 'using', 'email']
# ['parent', 'teacher', 'version-', 'receive', 'invite', 'microsoft', 'team', 'feedback', 'thought', 'book', 'question', 'choose', 'first', 'twitter']
# ['professor', 'insisting', 'lecture', 'microsoft', 'chill', 'lecture', 'pajama', 'prerecord', 'sessions']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'kijken', 'thanks']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'register', 'team', 'webinar', 'microsoftteams', 'offer', 'demand', 'training', 'video', 'setting', 'virtual', 'classroom', 'antigonish', 'technology', 'highered']
# ['professora', 'desenho', 'digital', 'postou', 'material', 'moodle', 'momento', 'chegou']
# ['professor', 'teoria', 'geral', 'política', 'marcando', 'prova', 'ficar', 'disponível', 'moodle', 'imagina', 'nível', 'dificuldade', 'essas', 'perguntas', 'disponibilizar', 'semana', '......']
# ['nycdoe', 'try', 'order', 'microsoft', 'privacy', 'issue', 'google', 'moodle', 'sweetheart', 'contract', 'making', 'nyccoronavirus', 'distress', 'student', 'teacher', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'remotelearning', 'remoteteaching']
# ['piorar', 'todos', 'professores', 'passando', 'atividades', 'trabalhos', 'moodle', 'surge', 'diferentão', 'google', 'classroom', 'ranço']
# ['TWITTER_HANDLE', 'clock', 'campaign', 'college', 'collage', 'canvas', 'counter', 'cricket', 'click', 'client', 'ceiling', 'chilli', 'chips', 'casino', 'casket', 'refreshwithgossychallenge']
# ['return', 'roots', 'harmony', 'start', 'making', 'canvas', 'good', 'employee', 'office', 'manager', 'soppa', 'sewing', 'mask', 'production', 'staff', 'child', 'teacher', 'harmony', 'learning', 'center', 'recycleharmony', 'careercommunityculture']
# ['fucking', 'murder', 'columbia', 'college', 'canvas', 'foundation']
# ['derek', 'jarman', 'portrait', 'canvas', 'fifties', 'derek', 'attend', 'college', 'paint', 'landscape', 'figurative', 'works', 'portrait', 'works', 'still', 'flower', 'painting', 'scene', 'everyday', 'TWITTER_HANDLE', 'lgbtq', 'painting']
# ['follow', 'along', 'child', 'remotelearning', 'parent', 'complete', 'coursework', 'canvas', 'request', 'access', 'child', 'teacher', 'follow', 'steps', 'castleberryisd', 'canvaslms', 'immslions', 'chs_lions']
# ['TWITTER_HANDLE', 'blackboard', 'university', 'happy', 'swap', 'moodle', 'blackboard', 'rely', 'patent', 'overturn', 'income']
# ['teacher', 'really', 'middle', 'night', 'add', 'blackboard', 'relax', 'somewhere']
# ['quarantine', 'kicking', 'teacher', 'ass', 'single', 'grade', 'blackboard']
# ['professor', 'spend', 'drive', 'computer', 'blackboard', 'everybody']
# ['online', 'class', 'stuff', 'professor', 'tell', 'minutes', 'class', 'class', 'blackboard', 'instructions']
# ['professor', 'number', 'email', 'operate', 'blackboard', 'concern']
# ['googleclassroom', 'million', 'teacher', 'student', 'around', 'world', 'teaching', 'learning']
# ['atividades', 'google', 'classroom', 'parecendo', 'quando', 'entrego', 'professores', 'jogam']
# ['TWITTER_HANDLE', 'wonder', 'teacher', 'experience', 'issue', 'assigning', 'google', 'drawing', 'assignment', 'google', 'classroom', 'assign', 'student', 'weird']
# ['student', 'receive', 'email', 'blackboard', 'collaborate', 'support', 'teacher', 'system', 'create', 'personalize', 'virtual', 'classroom', 'please', 'visit', 'grade', 'level', 'google', 'classroom']
# ['geographer', 'creative', 'entering', 'years', 'young', 'geographer', 'competition', 'theme', 'world', 'beyond', 'window', 'details', 'shard', 'google', 'classroom', 'question', 'teacher', 'geographyathome']
# ['kindergarten', 'teacher', 'philly', 'income', 'minority', 'background', 'try', 'google', 'classroom', 'student', 'worry', 'generation', 'behind']
# ['TWITTER_HANDLE', 'great', 'point', 'hear', 'TWITTER_HANDLE', 'guest', 'makelearningmagical', 'podcast', 'describe', 'pivot', 'pottery', 'teacher', 'remote', 'instruction', 'feedback', 'using', 'googleclassroom', 'TWITTER_HANDLE', 'playdough', 'totally', 'embracing', 'inspire']
# ['ninguém', 'passa', 'resolve', 'cinco', 'professores', 'passarem', 'trabalhos', 'mesmo', 'tempo', 'sinceramnete', 'tomar', 'fodase', 'merda', 'demais', 'moral', 'google', 'classroom', 'odeio', 'cansei', 'estudar']
# ['TWITTER_HANDLE', '2xweek', 'breakfast', 'lunch', 'everyday', 'assignment', 'google', 'classroom', 'teacher', 'office', 'hours', 'answer', 'email', 'video', 'suburb', 'cleveland', 'refugee', 'family']
# ['TWITTER_HANDLE', 'elementary', 'teacher', 'check', 'great', 'strategy', 'check', 'virtual', 'attendance', 'google', 'classroom', 'middle', 'folks', 'could', 'apply', 'similar', 'strategy', 'using', 'canvas']
# ['gmail', 'turn', 'within', 'district', 'teacher', 'click', 'email', 'student', 'google', 'classroom', 'email', 'route', 'microsoft', 'outlook', 'account', 'someone', 'situation']
# ['learning', 'relate', '-teachers', 'embed', 'links', 'learn', 'student', 'click', '-same', 'thing', 'google', 'classroom', 'learn360', 'click', 'share', 'option', 'select', 'google', 'classroom']
# ['também', 'conseguindo', 'focar', 'funciona', 'google', 'classroom', 'online', 'professor', 'tirar', 'dúvidas', 'prático', 'mandarem', 'exercícios', 'imagino', 'gênero', 'nunca']
# ['TWITTER_HANDLE', 'short', 'amount', 'field', 'semester', 'close', 'student', 'quickly', 'texting', 'mentor', 'teacher', 'would', 'could', 'apart', 'google', 'classroom', 'since', 'chance', 'goodbye', 'octmchat']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'using', 'google', 'classroom', 'grandma', 'retire', 'teacher']
# ['spanish', 'teacher', 'message', 'google', 'classroom', 'asking', 'playing', 'animal', 'crossing']
# ['TWITTER_HANDLE', 'looking', 'resource', 'teacher', 'begin', 'teaching', 'virtually', 'using', 'google', 'classroom', 'chance', 'could', 'point', 'toward', 'great', 'people', 'putting', 'awesome', 'content', 'maybe', 'could', 'check', 'classroom']
# ['student', 'quick', 'update', 'please', 'starting', 'check', 'google', 'classroom', 'email', 'account', 'teacher', 'starting', 'reach']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'absolutely', 'teach', 'elementary', 'teacher', 'sending', 'email', 'google', 'classroom', 'links', 'site', 'activity', 'grade', 'sitting', 'schoolwork']
# ['TWITTER_HANDLE', 'classroom', 'secondary', 'student', 'visit', 'learning', 'support', 'question', 'unable', 'contact', 'teacher', 'someone', '9:00am-', '1:30pm', 'monday', 'friday', 'TWITTER_HANDLE', 'TWITTER_HANDLE']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'google', 'classroom', 'answer', 'question']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'google', 'classroom']
# ['TWITTER_HANDLE', 'favorite', 'kindergarten', 'teacher', 'host', 'virtual', 'circle', 'google', 'TWITTER_HANDLE', 'first', 'comfortable', 'camera', 'first', 'grade', 'using', 'google', 'classroom', 'lady', 'heart', 'smiling']
# ['falcon', 'family', 'please', 'website', 'student', 'beginning', 'march', 'student', 'google', 'classroom', 'receive', 'assignment', 'directly', 'teacher']
# ['TWITTER_HANDLE', 'teacher', 'google', 'classroom', 'elementary', 'edchat', 'onlinelearning', 'googleclassroom']
# ['TWITTER_HANDLE', 'thing', 'close', 'school', 'assignment', 'teacher', 'assign', 'google', 'classroom', 'problem', 'solve', 'everyone', 'thing', 'pandemic', 'disease', 'right', 'thing']
# ['latest', 'eddie', 'interview', 'digitalization', 'energysector', 'representative', 'TWITTER_HANDLE', 'digitalenergyedu', 'digitallearning', 'erasmusplus', 'blueprint']
# ['obacht', 'sunsch', 'fuditätsch', 'spaziergänge', 'grünen', 'online', 'rundgänge', 'schönsten', 'städten', 'europa', 'virtuelle', 'apéros', '️1mai', 'dehai', 'noflashmob', 'chbeatscovid', 'siebenbraufeinenstreich']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'online', 'delivery', 'essential', 'dhayan', 'khali', 'jhaado', 'power', 'dikhao', 'khudke', 'batti', 'chinta', 'sakhti', 'mahine', 'covid', 'protocol', 'naubat', 'dhakausla', 'power']
# ['conduct', 'online', 'class', 'online', 'exam', 'kid', 'donotpostponeexams', 'wewantdualmodeofexams', 'studentscareermatter', 'gauhatiuniversity', 'studentslivesmatters', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE']
# ['already', '6months', 'behind', 'notice', 'class', 'conduct', 'online', 'whynot', 'exam', 'donotpostponeexams', 'wewantdualmodeofexams', 'studentscareermatter', 'gauhatiuniversity', 'studentslivesmatter', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE']
# ['TWITTER_HANDLE', 'really', 'group', 'online', 'really', 'tense', 'friend', 'really', 'friendly']
# ['TWITTER_HANDLE', 'tenho', 'parente', 'filhos', 'tavam', 'online', 'quando', 'pensaram', 'voltar', 'ficaram', 'sabendo', 'tinha', 'crianças', 'covid']
# ['miss', 'twitter', 'allow', 'anything', 'football', 'super', 'league', 'talking', 'covid', 'online', 'abuse', 'racism', 'without', 'feeling', 'better']
# ['TWITTER_HANDLE', 'honestly', 'pernah', 'tugas', 'waktu', 'pengaruh', 'ekonomi', 'sebenarnya', 'bukan', 'bangga', 'kebutuhan', 'ekonomi', 'tugas', 'offline', 'skrng', 'online', 'lebuh', 'mudahh']
# ['workplace', 'lesson', 'learn', 'covid-19', 'professional', 'organization', 'learn', 'working', 'covid-19', 'online', 'collect', 'following', 'response', 'pandemic', 'change']
# ['legal', 'change', 'indian', 'government', 'decolonisation', 'process', 'result', 'growth', 'pharmaceutical', 'capacity', 'TWITTER_HANDLE', 'online', 'discussion', 'covid-19', 'vaccination', 'southasia']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'please', 'quick', 'decision', 'rajasthan', 'board', 'exam', '........', 'request', '.......', 'please', 'life', 'student', 'either', 'conduct', 'exam', 'online', 'cancel', 'exam', 'covid-19', 'case', 'increase', 'rajasthan', 'rapid']
# ['TWITTER_HANDLE', 'kampus', 'wacana', 'bakal', 'kampus', 'jdinya', 'online', 'optimis', 'offline', 'cepet', 'susah']
# ['TWITTER_HANDLE', 'teacher', 'friend', 'expect', 'teach', 'class', 'online', 'caring', 'toddler', 'working', 'homeschooling', 'month', 'break', 'system', 'strap', 'mother', 'burden', 'government', 'would']
# ['alestecovidvar', 'temmuzda', 'sınavlar', 'online', 'bizim', 'sinavımız', 'ertelenmedı', 'duyun', 'sayın', 'hocam', 'TWITTER_HANDLE', 'TWITTER_HANDLE']
# ['TWITTER_HANDLE', 'hate', 'first', 'online', 'class', 'heartbreaking', 'listening', 'understand', 'teacher', 'school', 'allow', 'eventually', 'point', 'miss', 'maybe']
# ['28need', 'affordable', 'winter', 'class', 'probability', 'mathlab', 'campus', 'social', 'science', 'homework', 'music', 'analysis', 'assignment', 'college', 'geometry', 'trigonometry', 'business', 'canvas', 'online', 'college', 'class', 'anatomy', 'practice', 'exercise', 'whatsapp']
# ['TWITTER_HANDLE', 'masih', 'ngajar', 'online', 'rumah', 'reflek', 'mute', 'dangdut', 'keras2']
# ['literally', 'college', 'motivation', 'whatsoever', 'tire', 'depress', 'professor', 'teach', 'online', 'lucky', 'class']
# ['scammer', 'doubling', 'effort', 'people', 'money', 'personal', 'information', 'team', 'remind', 'covid-19', 'vaccine', 'online', 'pocket', 'shot']
# ['exxon', 'want', 'russia', 'moneywatch', 'headline', 'bankingandfinancenews', 'covid19', 'online', 'banking', 'business', 'services', 'finance', 'money', 'lease', 'lending', 'market', 'please', 'retweet']
# ['class', 'kahit', 'covid-19', 'mamamatay', 'nakakamatay', 'online', 'class', 'radiation', 'depression', 'stress', 'anxiety', 'loads', 'pandemyang']
# ['starting', 'every', 'ontario', 'adult', 'eligible', 'covid-19', 'vaccine', 'appointment', 'using', 'online', 'provincial', 'booking', 'system', 'welcome', 'everyone', 'want', 'vaccinate', 'covid-19']
# ['teacherlife', 'teacher', 'teaching', 'teachertwitter', 'distancelearning', 'edtech', 'edtechtips', 'edtechchat', 'learning', 'teachertips', 'edtechteachers', 'virtuallearning', 'remotelearning', 'blendedlearning', 'teachershelpingteachers']
# ['ferguson', 'easley', 'teacher', 'getting', 'ready', 'itsthefinalcountdown', 'blendedlearning', 'schoolsareopeningsoon', 'thefergusoneasley', 'feesallstars', 'thisis2021', 'TWITTER_HANDLE', 'fearlessleader']
# ['asynchronous', 'video', 'handy', '112leads', 'raviniarocks', 'd112teachers']
# ['proposal', 'include', 'asynchronous', 'class', 'april', 'consideration', 'professor', 'avoid', 'giving', 'requirement', 'extension', 'deadline', 'asynchronous', 'online', 'examination']
# ['expand', 'access', 'devices', 'internet', 'TWITTER_HANDLE', 'support', 'remote', 'hybrid', 'learning', 'TWITTER_HANDLE', 'student', 'covid-19']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'hybrid', 'education', 'happen', 'college', 'student', 'september']
# ['covid-19', 'vaccine', 'rollout', 'continue', 'consumer', 'begin', 'gradual', 'return', 'pandemic', 'normality', 'marketer', 'expect', 'event', 'future', 'hybrid', 'person', 'virtual', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'marketing', 'advertising', 'branding']
# ['opinion', 'hybrid', 'learning', 'herd', 'community', 'tmrletter', 'covid19', 'education', 'learning']
# ['TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'sorry', 'parent', 'understand', 'hybrid', 'happen', 'since', 'social', 'distance', 'student', 'attend', 'school', 'since', 'magically', 'teacher', 'classroom', 'pandemic-']
# ['reopen', 'sfusd', 'middle', 'school', 'suffering', 'need', 'support', 'teacher', 'person', 'hybrid', 'please', 'mental', 'health', 'fragile', 'tip', 'point', 'student', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE']
# ['student', 'teacher', 'staff', 'starting', 'hybrid', 'learning', 'welcome', 'classroom', 'proud', 'district', 'educator', 'staff', 'parent', 'working', 'together', 'bring', 'student', 'safely', 'school']
# ['TWITTER_HANDLE', 'educate', 'state', 'teacher', 'teaching', 'person', 'online', 'hybrid', 'stressful', 'midst', 'pandemic', 'sometimes', 'little', 'cling', 'try', 'supervise', 'child']
# ['report', 'envoy', 'outline', 'workforce', 'sentiment', 'office', 'safety', 'coronavirus', 'pandemic', 'employer', 'mandate', 'inoculation', 'hybrid', 'preference']
# ['TWITTER_HANDLE', 'please', 'hybrid', 'option', 'grader', 'school', 'especially', 'vulnerable', 'family', 'covid', 'apply', 'virtual', 'charter', 'school', 'public', 'school', 'public', 'thank']
# ['teacher', 'school', 'whatever', 'worst', 'possible', 'grade', 'foreseeable', 'future']
# ['event', 'event', 'platform', '81410922118', 'password', '510928', 'onlinesessions', 'webinars', 'corona', 'covid19', 'sageuniversity', 'sageindore', 'sagebhopal']
# ['getting', 'visibly', 'annoy', 'people', 'class', 'following', 'direction', 'better', 'turning', 'anything', 'praise', 'teacher', 'round', 'applause', 'excellent', 'still', 'try']
# ['piano', 'teacher', 'drink', 'teaching', 'trope', 'TWITTER_HANDLE', 'taking', 'question']
# ['post', 'photo', 'TWITTER_HANDLE', 'university']
# ['conferència', 'projecte', 'TWITTER_HANDLE', 'formación', 'integral', 'deportista', 'estrategias', 'prácticas', 'TWITTER_HANDLE', 'fundador', 'president', 'TWITTER_HANDLE', 'professor', 'associat', 'TWITTER_HANDLE', 'esport', '04/05', '19:00', '20:30', '️inscripcions', '02/05']
# ['nearly', 'virtual', 'career', 'event', 'adult', 'booking', 'close', 'tomorrow', 'sessions', 'expert', 'guest', 'speaker', 'apprenticeship', 'further', 'careersadvice', 'university', 'mondaymotivation', 'thurrock']
# ['teacher', 'accept', 'sleep']
# ['hello', 'everyone', 'young', 'teens', 'organize', 'online', 'event', 'event', 'people', 'diagnose', 'covid-19', 'solitude', 'concert', 'fill', 'music', 'poetry', 'positive', 'things', 'please', 'register']
# ['mutual', 'hotline', 'session', 'tomorrow', 'first', 'joining', 'contact', 'stlcovidaid@gmail.com', 'attend', 'stlma']
# ['TWITTER_HANDLE', 'covid', 'blessing', 'hate', 'call', 'sales', 'meeting', 'phone', 'email']
# ['basically', 'attend', 'panel', 'talk', 'biden', 'first', 'ask', 'really', 'spicy', 'question', 'older', 'white', 'professor', 'email', 'saying', 'happy', 'participate', 'better']
# ['securely', 'across', 'devices', 'TWITTER_HANDLE', 'show', 'microsoft', 'help', 'nonprofit', 'organization', 'secure', 'working', 'remotely', 'coronavirus', 'mandate', 'TWITTER_HANDLE']
# ['microsoft', 'team', 'higher', 'education', 'study', 'calling', 'value', 'integrate', 'communications', 'pandemic', 'response', 'period', 'distance', 'teaching', 'learning', 'customer', 'leveraging', 'integrate', 'comms', 'y5wpli2gn5']
# ['didaktik', 'cmaps', 'arbeitsblätter', 'einführung', 'tool', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'TWITTER_HANDLE', 'greeting', 'berlin', 'germany', 'homeoffice', 'lockdown', 'zerocovid', 'moodle']
# ['student', 'college', 'wellbeing', 'organise', 'monthly', 'thursday', 'group', 'session', 'starting', 'thursday', 'march', 'informal', 'student', 'wellbeing', 'moodle']
# ['affordable', 'online', 'class', 'probability', 'mathlab', 'campus', 'social', 'science', 'homework', 'analysis', 'assignment', 'geometry', 'trigonometry', 'canvas', 'college', 'anatomy', 'mathxl', 'practice', 'exercise', 'journal', 'article', 'pharmacy', 'psychology', 'assignment', 'stats']
# ['teacher', 'message', 'canvas']
# ['TWITTER_HANDLE', 'found', 'canvas', 'problem', 'funny', 'student', 'teachershirt']
# ['essay', '|#assignment', 'homework|', 'onlineclass', 'calculus|', 'statistics|', 'physics|', 'labreport', 'canva', 'blackboard', 'email', 'prowritersusa@gmail.com', 'whatsapp:+1(505)709', 'legit', 'timely', 'collgestudents', 'collegeassignment', 'collegelifestyle']
# ['TWITTER_HANDLE', 'parent', 'sharing', 'could', 'track', 'schoolwork', 'teacher', 'recommend', 'totally', 'works', 'google', 'classroom', 'user']
# ['anyone', 'try', 'google', 'classroom', 'friend', 'actually', 'college']
# ['millennial', 'teacher', 'include', 'using', 'discord', 'class', 'instead', 'google', 'classroom']

# %%
# Create dataframe with the cols we need
df = pd.DataFrame({'tweet':text_data, 
                   'sentiment':data['vader_com'], 
                   'year':data['year']})
df.head()
# Out:
#                                                tweet  sentiment  year
# 0  [eteacher, provide, personalize, assistance, l...     0.0000  2020
# 1  [civil, engineering, department, college, tech...     0.5106  2020
# 2  [host, google, end, listening, freeze, sound, ...     0.8519  2020
# 3  [super, special, effects, broadcast, TWITTER_H...     0.7906  2020
# 4  [talented, reporting, digital, learning, TWITT...     0.3400  2020

# %%
# Remove TWITTER_HANDLE from tweets 
for i in range(len(df)):
  try:
    df['tweet'][i].remove("TWITTER_HANDLE")
  except:
    continue

# Verify it worked correctly. 
df.head()
# Out:
#                                                tweet  sentiment  year
# 0  [eteacher, provide, personalize, assistance, l...     0.0000  2020
# 1  [civil, engineering, department, college, tech...     0.5106  2020
# 2  [host, google, end, listening, freeze, sound, ...     0.8519  2020
# 3  [super, special, effects, broadcast, feature, ...     0.7906  2020
# 4  [talented, reporting, digital, learning, featu...     0.3400  2020

# %% [markdown]
# ## Wordclouds

# %%
# Make sure the cols are numeric
df['sentiment'] = df['sentiment'].astype(float)
df['year'] = df['year'].astype(int)

# %%
# Separate positive vs. negative, 2020 vs. 2021
pos_20 = df[(df['year']==2020) & (df['sentiment']>=0.5)].reset_index(drop=True)
pos_21 = df[(df['year']==2021) & (df['sentiment']>=0.5)].reset_index(drop=True)
neg_20 = df[(df['year']==2020) & (df['sentiment']<=-0.5)].reset_index(drop=True)
neg_21 = df[(df['year']==2021) & (df['sentiment']<=-0.5)].reset_index(drop=True)

# %%
# Import wordcloud library
from wordcloud import WordCloud

trouble_list = ['amp', 'gt', '30pm', '30am', '00am', '00pm', 'lt', '15pm', 
                'org', 'edu']

# Join all  tweets together
list_all_tweets = list(set([a for b in df['tweet'].tolist() for a in b]))
all_tweets = ", ".join(list_all_tweets)
for i in trouble_list:
  try:
    all_tweets = all_tweets.replace(i, "")
  except:
    continue

# Join positive from 2020 together
list_l_str_p20 = list(set([a for b in pos_20['tweet'].tolist() for a in b]))
l_str_p20 = ", ".join(list_l_str_p20)
for i in trouble_list:
  try:
    l_str_p20 = l_str_p20.replace(i, "")
  except:
    continue

# Join positive from 2021 together
list_l_str_p21 = list(set([a for b in pos_21['tweet'].tolist() for a in b]))
l_str_p21 = ", ".join(list_l_str_p21)
for i in trouble_list:
  try:
    l_str_p21 = l_str_p21.replace(i, "")
  except:
    continue

# Join negative from 2020 together
list_l_str_n20 = list(set([a for b in neg_20['tweet'].tolist() for a in b]))
l_str_n20 = ", ".join(list_l_str_n20)
for i in trouble_list:
  try:
    l_str_n20 = l_str_n20.replace(i, "")
  except:
    continue

# Join negative from 2021 together
list_l_str_n21 = list(set([a for b in neg_21['tweet'].tolist() for a in b]))
l_str_n21 = ", ".join(list_l_str_n21)
for i in trouble_list:
  try:
    l_str_n21 = l_str_n21.replace(i, "")
  except:
    continue

# %%
# Create wordcloud objects
title_list = ['All Tweets', 
              'Positive-2020', 'Positive-2021', 
              'Negative-2020', 'Negative-2021']
position = 0 
for item in [all_tweets, l_str_p20, l_str_p21, l_str_n20, l_str_n21]:
    plt.figure(figsize=(10, 7))
    wordcloud = WordCloud(background_color='white', max_words=2000, 
                      contour_width=3, contour_color='steelblue', 
                      collocations=True)
    item 
    wordcloud.generate(item)
    wordcloud.to_image()
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title_list[position], fontsize=30, pad=40)
    plt.savefig(f'word_cloud_{title_list[position]}.png')
    plt.show()
    position+=1
    print("\n\n")

# %% [markdown]
# ## LDA with Gensim

# %%
# LDA for all tweets
import warnings
warnings.filterwarnings("ignore")
all_lda = lda_model_grid(df=df, col='tweet')
line_plot(df=all_lda, col='complexity', save_name='complexity_all')
line_plot(df=all_lda, col='coherence', save_name='coherence_all')
# Out:
# Checking model with 2 topics.
# Checking model with 3 topics.
# Checking model with 4 topics.
# Checking model with 5 topics.
# Checking model with 6 topics.
# Checking model with 7 topics.
# Checking model with 8 topics.
# Checking model with 9 topics.

# %%
# LDA for positive tweets from 2020
pos_20_lda = lda_model_grid(df=pos_20, col='tweet')
line_plot(df=pos_20_lda, col='complexity', save_name='complexity_pos20')
line_plot(df=pos_20_lda, col='coherence', save_name='coherence_pos_20')
# Out:
# Checking model with 2 topics.
# Checking model with 3 topics.
# Checking model with 4 topics.
# Checking model with 5 topics.
# Checking model with 6 topics.
# Checking model with 7 topics.
# Checking model with 8 topics.
# Checking model with 9 topics.

# %%
# LDA for positive tweets from 2021
pos_21_lda = lda_model_grid(df=pos_21, col='tweet')
line_plot(df=pos_21_lda, col='complexity', save_name='complexity_pos_21')
line_plot(df=pos_21_lda, col='coherence', save_name='coherence_pos_21')
# Out:
# Checking model with 2 topics.
# Checking model with 3 topics.
# Checking model with 4 topics.
# Checking model with 5 topics.
# Checking model with 6 topics.
# Checking model with 7 topics.
# Checking model with 8 topics.
# Checking model with 9 topics.

# %%
# LDA for negative tweets from 2020
neg_20_lda = lda_model_grid(df=neg_20, col='tweet')
line_plot(df=neg_20_lda, col='complexity', save_name='complexity_neg_20')
line_plot(df=neg_20_lda, col='coherence', save_name='coherence_neg_20')
# Out:
# Checking model with 2 topics.
# Checking model with 3 topics.
# Checking model with 4 topics.
# Checking model with 5 topics.
# Checking model with 6 topics.
# Checking model with 7 topics.
# Checking model with 8 topics.
# Checking model with 9 topics.

# %%
# LDA for negative tweets from 2021
neg_21_lda = lda_model_grid(df=neg_21, col='tweet')
line_plot(df=neg_21_lda, col='complexity', save_name='complexity_neg_21')
line_plot(df=neg_21_lda, col='coherence', save_name='coherence_neg_21')
# Out:
# Checking model with 2 topics.
# Checking model with 3 topics.
# Checking model with 4 topics.
# Checking model with 5 topics.
# Checking model with 6 topics.
# Checking model with 7 topics.
# Checking model with 8 topics.
# Checking model with 9 topics.

# %% [markdown]
# ## Build topic models using the least complex and most coherent number of topics.

# %%
# All tweets = 4 topics
all_topics = lda_one_topic(df=df, col='tweet', topics=6, savename='all_tweets')

# %%
# Positive from 2020 tweets = 4 topics
p20_topics = lda_one_topic(df=pos_20, col='tweet', topics=7, savename='p20_tweets')

# %%
# Positive from 2021 tweets = 4 topics
p21_topics = lda_one_topic(df=pos_21, col='tweet', topics=7, savename='p21_tweets')

# %%
# Negative from 2020 tweets = 5 topics
n20_topics = lda_one_topic(df=neg_20, col='tweet', topics=7, savename='n20_tweets')

# %%
# Negative from 2021 tweets = 5 topics
n21_topics = lda_one_topic(df=neg_21, col='tweet', topics=6, savename='n21_tweets')
